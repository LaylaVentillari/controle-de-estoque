# %%
import pandas as pd

# %%
# !pip install pdf-reports
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pdf_reports import pug_to_html, write_report
import datetime

# %%
controle_de_abacates = pd.read_excel("/content/controle_de_abacates.xlsx")

# %%
controle_de_abacates
# Out:
#     id       data  preco_medio  volume_total          tipo   ano
# 0    1 2017-01-01         2.06      39260.55      Orgânico  2017
# 1    2 2017-01-08         2.15      42755.80      Orgânico  2017
# 2    3 2017-01-15         2.09      42233.25      Orgânico  2017
# 3    4 2017-01-22         2.05      49056.11      Orgânico  2017
# 4    5 2017-01-29         2.08      46602.16  Convencional  2017
# ..  ..        ...          ...           ...           ...   ...
# 60  61 2018-02-25         1.72     112128.84      Orgânico  2018
# 61  62 2018-03-04         1.69     133768.12      Orgânico  2018
# 62  63 2018-03-11         1.92     108114.03  Convencional  2018
# 63  64 2018-03-18         1.70     189434.04  Convencional  2018
# 64  65 2018-03-25         1.86     118503.55  Convencional  2018
#
# [65 rows x 6 columns]

# %%
controle_de_abacates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            65 non-null     int64
#  1   data          65 non-null     datetime64[ns]
#  2   preco_medio   65 non-null     float64
#  3   volume_total  65 non-null     float64
#  4   tipo          65 non-null     object
#  5   ano           65 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 3.2+ KB

# %%
controle_de_abacates.describe()
# Out:
#              id  preco_medio   volume_total          ano
# count  65.00000    65.000000      65.000000    65.000000
# mean   33.00000     2.000154   96707.269538  2017.184615
# std    18.90767     0.226498   71485.991993     0.391005
# min     1.00000     1.360000   39260.550000  2017.000000
# 25%    17.00000     1.850000   69777.300000  2017.000000
# 50%    33.00000     2.030000   75462.110000  2017.000000
# 75%    49.00000     2.090000   95299.690000  2017.000000
# max    65.00000     2.480000  495083.690000  2018.000000

# %%
controle_de_abacates["volume_total"].sum()
# Out:
# 6285972.52

# %%
controle_de_abacates.plot("data", "preco_medio")

# %%
planilha_nova = pd.read_excel("/content/controle_de_abacates_atualizado.xlsx")

# %%
html = pug_to_html("/content/modelo_de_relatorio.pug", planilha = planilha_nova, hoje = "2022-01-06")

# %%
html
# Out:
# '<style lang="scss">@page {\n  margin: 1cm 0 2cm 0cm;\n  @bottom-center {\n    content: "";\n  }\n}\n</style><img style="width:150px; display:block; margin:0 auto;" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png"/>\n<div id="sidebar">\n  <p>Atualizado por Carlos Melo - 2022-01-06</p>\n</div>\n<h1>Relatório de Controle de Abacates</h1>\n<div class="ui piled segment">\n  <p>Este relatório é parte de um exercício prático da Semana Python, evento online gratuito do\n<a href="https://sigmoidal.ai">Sigmoidal</a>, e tem a finalidade de divulgar e promover \nPython e Data Science no Brasil.\n  </p>\n</div>\n<p><strong><em>Gerado automaticamente e conferido pelo analista Carlos Melo.</em></strong></p>\n<p><code>controle_abacates_2022-01-06.pdf</code></p>\n<p>Para maiores informações sobre o autor da Semana Python, acesso o <a href="http://linkedin.com/in/carlosfab/">perfil do LinkedIn</a> \ne siga o <a href="http://youtube.com/c/carlosme
# ...

# %%
write_report(html, "controle_de_abacates_relatorio.pdf")
# Out:
# WARNING:weasyprint:Invalid or unsupported selector '[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner', (<IdentToken -moz-focus-inner>, 'Expected a supported pseudo-element, got -moz-focus-inner')
# WARNING:weasyprint:Ignored `outline:1px dotted ButtonText` at 19:1828, invalid value.
# WARNING:weasyprint:Invalid or unsupported selector '[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button', (<IdentToken -webkit-inner-spin-button>, 'Expected a supported pseudo-element, got -webkit-inner-spin-button')
# WARNING:weasyprint:Ignored `outline-offset:-2px` at 19:2330, unknown property.
# WARNING:weasyprint:Invalid or unsupported selector '::-webkit-file-upload-button', (<IdentToken -webkit-file-upload-button>, 'Expected a supported pseudo-element, got -webkit-file-upload-button')
# WARNING:weasyprint:Ignored `overflow-x:hidden` at 27:70, unknown property.
# ...
